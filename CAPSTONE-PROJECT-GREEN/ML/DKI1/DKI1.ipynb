# %% [markdown]
# ## train pm10 library

# %%
import d1pm10 as pm10

# %% [markdown]
# ## train pm25 library

# %%
import d1pm25 as pm25
# Out:
# Epoch 1/70
# 10/10 [==============================] - 0s 3ms/step - loss: 91.4564 - lr: 1.0000e-08
# Epoch 2/70
# 10/10 [==============================] - 0s 2ms/step - loss: 91.4387 - lr: 1.1220e-08
# Epoch 3/70
# 10/10 [==============================] - 0s 2ms/step - loss: 91.4115 - lr: 1.2589e-08
# Epoch 4/70
# 10/10 [==============================] - 0s 3ms/step - loss: 91.3785 - lr: 1.4125e-08
# Epoch 5/70
# 10/10 [==============================] - 0s 2ms/step - loss: 91.3407 - lr: 1.5849e-08
# Epoch 6/70
# 10/10 [==============================] - 0s 2ms/step - loss: 91.2975 - lr: 1.7783e-08
# Epoch 7/70
# 10/10 [==============================] - 0s 2ms/step - loss: 91.2481 - lr: 1.9953e-08
# Epoch 8/70
# 10/10 [==============================] - 0s 2ms/step - loss: 91.1935 - lr: 2.2387e-08
# Epoch 9/70
# 10/10 [==============================] - 0s 2ms/step - loss: 91.1309 - lr: 2.5119e-08
# Epoch 10/70
# ...

# %% [markdown]
# ## train so2 library

# %%
import d1so2 as so2
# Out:
# Epoch 1/70
# 10/10 [==============================] - 0s 3ms/step - loss: 24.0875 - lr: 1.0000e-08
# Epoch 2/70
# 10/10 [==============================] - 0s 2ms/step - loss: 24.0866 - lr: 1.1220e-08
# Epoch 3/70
# 10/10 [==============================] - 0s 3ms/step - loss: 24.0852 - lr: 1.2589e-08
# Epoch 4/70
# 10/10 [==============================] - 0s 3ms/step - loss: 24.0836 - lr: 1.4125e-08
# Epoch 5/70
# 10/10 [==============================] - 0s 3ms/step - loss: 24.0817 - lr: 1.5849e-08
# Epoch 6/70
# 10/10 [==============================] - 0s 2ms/step - loss: 24.0796 - lr: 1.7783e-08
# Epoch 7/70
# 10/10 [==============================] - 0s 3ms/step - loss: 24.0772 - lr: 1.9953e-08
# Epoch 8/70
# 10/10 [==============================] - 0s 3ms/step - loss: 24.0745 - lr: 2.2387e-08
# Epoch 9/70
# 10/10 [==============================] - 0s 2ms/step - loss: 24.0715 - lr: 2.5119e-08
# Epoch 10/70
# ...

# %% [markdown]
# ## train co library

# %%
import d1co as co
# Out:
# Epoch 1/70
# 10/10 [==============================] - 0s 2ms/step - loss: 13.9464 - lr: 1.0000e-08
# Epoch 2/70
# 10/10 [==============================] - 0s 2ms/step - loss: 13.9451 - lr: 1.1220e-08
# Epoch 3/70
# 10/10 [==============================] - 0s 2ms/step - loss: 13.9431 - lr: 1.2589e-08
# Epoch 4/70
# 10/10 [==============================] - 0s 2ms/step - loss: 13.9408 - lr: 1.4125e-08
# Epoch 5/70
# 10/10 [==============================] - 0s 1ms/step - loss: 13.9380 - lr: 1.5849e-08
# Epoch 6/70
# 10/10 [==============================] - 0s 1ms/step - loss: 13.9350 - lr: 1.7783e-08
# Epoch 7/70
# 10/10 [==============================] - 0s 2ms/step - loss: 13.9315 - lr: 1.9953e-08
# Epoch 8/70
# 10/10 [==============================] - 0s 2ms/step - loss: 13.9277 - lr: 2.2387e-08
# Epoch 9/70
# 10/10 [==============================] - 0s 2ms/step - loss: 13.9234 - lr: 2.5119e-08
# Epoch 10/70
# ...

# %% [markdown]
# ## train o3 library

# %%
import d1o3 as o3
# Out:
# Epoch 1/70
# 10/10 [==============================] - 0s 2ms/step - loss: 21.5129 - lr: 1.0000e-08
# Epoch 2/70
# 10/10 [==============================] - 0s 2ms/step - loss: 21.5127 - lr: 1.1220e-08
# Epoch 3/70
# 10/10 [==============================] - 0s 3ms/step - loss: 21.5122 - lr: 1.2589e-08
# Epoch 4/70
# 10/10 [==============================] - 0s 2ms/step - loss: 21.5117 - lr: 1.4125e-08
# Epoch 5/70
# 10/10 [==============================] - 0s 2ms/step - loss: 21.5112 - lr: 1.5849e-08
# Epoch 6/70
# 10/10 [==============================] - 0s 2ms/step - loss: 21.5105 - lr: 1.7783e-08
# Epoch 7/70
# 10/10 [==============================] - 0s 2ms/step - loss: 21.5097 - lr: 1.9953e-08
# Epoch 8/70
# 10/10 [==============================] - 0s 2ms/step - loss: 21.5089 - lr: 2.2387e-08
# Epoch 9/70
# 10/10 [==============================] - 0s 3ms/step - loss: 21.5079 - lr: 2.5119e-08
# Epoch 10/70
# ...

# %% [markdown]
# ## train no2 library

# %%
import d1no2 as no2
# Out:
# Epoch 1/70
# 10/10 [==============================] - 0s 2ms/step - loss: 42.7624 - lr: 1.0000e-08
# Epoch 2/70
# 10/10 [==============================] - 0s 2ms/step - loss: 42.7553 - lr: 1.1220e-08
# Epoch 3/70
# 10/10 [==============================] - 0s 2ms/step - loss: 42.7443 - lr: 1.2589e-08
# Epoch 4/70
# 10/10 [==============================] - 0s 2ms/step - loss: 42.7309 - lr: 1.4125e-08
# Epoch 5/70
# 10/10 [==============================] - 0s 2ms/step - loss: 42.7155 - lr: 1.5849e-08
# Epoch 6/70
# 10/10 [==============================] - 0s 2ms/step - loss: 42.6978 - lr: 1.7783e-08
# Epoch 7/70
# 10/10 [==============================] - 0s 2ms/step - loss: 42.6781 - lr: 1.9953e-08
# Epoch 8/70
# 10/10 [==============================] - 0s 2ms/step - loss: 42.6558 - lr: 2.2387e-08
# Epoch 9/70
# 10/10 [==============================] - 0s 2ms/step - loss: 42.6306 - lr: 2.5119e-08
# Epoch 10/70
# ...

# %% [markdown]
# ## show output date

# %%
input = '2021-11-12'
print(pm10.pm10(input))
print(pm25.pm25(input))
print(so2.so2(input))
print(co.co(input))
print(o3.o3(input))
print(no2.no2(input))
# Out:
#        tanggal      Value
# 15  2021-11-12  48.541721
#        tanggal     Value
# 15  2021-11-12  62.66851
#        tanggal      Value
# 15  2021-11-12  32.155918
#        tanggal      Value
# 15  2021-11-12  13.524276
#        tanggal      Value
# 15  2021-11-12  19.689129
#        tanggal      Value
# 15  2021-11-12  35.064335
