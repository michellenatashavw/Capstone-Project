# %% [markdown]
# ## train pm10 library

# %%
import d1pm10 as pm10
# Out:
# 2022-05-23 21:09:37.954429: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-05-23 21:09:37.954473: E tensorflow/stream_executor/cuda/cuda_driver.cc:313] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-05-23 21:09:37.954498: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (yance-pc): /proc/driver/nvidia/version does not exist
# 2022-05-23 21:09:37.954776: I tensorflow/core/platform/cpu_feature_guard.cc:143] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2022-05-23 21:09:37.980843: I tensorflow/core/platform/profile_utils/cpu_utils.cc:102] CPU Frequency: 2294655000 Hz
# ...

# %% [markdown]
# ## train pm25 library

# %%
import d1pm25 as pm25
# Out:
# Epoch 1/70
# 10/10 [==============================] - 0s 3ms/step - loss: 83.7251 - lr: 1.0000e-08
# Epoch 2/70
# 10/10 [==============================] - 0s 4ms/step - loss: 83.6816 - lr: 1.1220e-08
# Epoch 3/70
# 10/10 [==============================] - 0s 3ms/step - loss: 83.6145 - lr: 1.2589e-08
# Epoch 4/70
# 10/10 [==============================] - 0s 3ms/step - loss: 83.5322 - lr: 1.4125e-08
# Epoch 5/70
# 10/10 [==============================] - 0s 3ms/step - loss: 83.4369 - lr: 1.5849e-08
# Epoch 6/70
# 10/10 [==============================] - 0s 2ms/step - loss: 83.3285 - lr: 1.7783e-08
# Epoch 7/70
# 10/10 [==============================] - 0s 2ms/step - loss: 83.2052 - lr: 1.9953e-08
# Epoch 8/70
# 10/10 [==============================] - 0s 2ms/step - loss: 83.0665 - lr: 2.2387e-08
# Epoch 9/70
# 10/10 [==============================] - 0s 2ms/step - loss: 82.9118 - lr: 2.5119e-08
# Epoch 10/70
# ...

# %% [markdown]
# ## train so2 library

# %%
import d1so2 as so2
# Out:
# Epoch 1/70
# 10/10 [==============================] - 0s 2ms/step - loss: 19.6507 - lr: 1.0000e-08
# Epoch 2/70
# 10/10 [==============================] - 0s 3ms/step - loss: 19.6479 - lr: 1.1220e-08
# Epoch 3/70
# 10/10 [==============================] - 0s 2ms/step - loss: 19.6435 - lr: 1.2589e-08
# Epoch 4/70
# 10/10 [==============================] - 0s 2ms/step - loss: 19.6381 - lr: 1.4125e-08
# Epoch 5/70
# 10/10 [==============================] - 0s 2ms/step - loss: 19.6320 - lr: 1.5849e-08
# Epoch 6/70
# 10/10 [==============================] - 0s 2ms/step - loss: 19.6251 - lr: 1.7783e-08
# Epoch 7/70
# 10/10 [==============================] - 0s 2ms/step - loss: 19.6174 - lr: 1.9953e-08
# Epoch 8/70
# 10/10 [==============================] - 0s 2ms/step - loss: 19.6086 - lr: 2.2387e-08
# Epoch 9/70
# 10/10 [==============================] - 0s 2ms/step - loss: 19.5989 - lr: 2.5119e-08
# Epoch 10/70
# ...

# %% [markdown]
# ## train co library

# %%
import d1co as co
# Out:
# Epoch 1/70
# 10/10 [==============================] - 0s 3ms/step - loss: 11.0879 - lr: 1.0000e-08
# Epoch 2/70
# 10/10 [==============================] - 0s 2ms/step - loss: 11.0862 - lr: 1.1220e-08
# Epoch 3/70
# 10/10 [==============================] - 0s 2ms/step - loss: 11.0835 - lr: 1.2589e-08
# Epoch 4/70
# 10/10 [==============================] - 0s 3ms/step - loss: 11.0802 - lr: 1.4125e-08
# Epoch 5/70
# 10/10 [==============================] - 0s 3ms/step - loss: 11.0764 - lr: 1.5849e-08
# Epoch 6/70
# 10/10 [==============================] - 0s 2ms/step - loss: 11.0721 - lr: 1.7783e-08
# Epoch 7/70
# 10/10 [==============================] - 0s 2ms/step - loss: 11.0673 - lr: 1.9953e-08
# Epoch 8/70
# 10/10 [==============================] - 0s 3ms/step - loss: 11.0619 - lr: 2.2387e-08
# Epoch 9/70
# 10/10 [==============================] - 0s 2ms/step - loss: 11.0558 - lr: 2.5119e-08
# Epoch 10/70
# ...

# %% [markdown]
# ## train o3 library

# %%
import d1o3 as o3
# Out:
# Epoch 1/70
# 10/10 [==============================] - 0s 2ms/step - loss: 25.0407 - lr: 1.0000e-08
# Epoch 2/70
# 10/10 [==============================] - 0s 2ms/step - loss: 25.0390 - lr: 1.1220e-08
# Epoch 3/70
# 10/10 [==============================] - 0s 2ms/step - loss: 25.0364 - lr: 1.2589e-08
# Epoch 4/70
# 10/10 [==============================] - 0s 3ms/step - loss: 25.0332 - lr: 1.4125e-08
# Epoch 5/70
# 10/10 [==============================] - 0s 2ms/step - loss: 25.0296 - lr: 1.5849e-08
# Epoch 6/70
# 10/10 [==============================] - 0s 2ms/step - loss: 25.0255 - lr: 1.7783e-08
# Epoch 7/70
# 10/10 [==============================] - 0s 3ms/step - loss: 25.0209 - lr: 1.9953e-08
# Epoch 8/70
# 10/10 [==============================] - 0s 3ms/step - loss: 25.0157 - lr: 2.2387e-08
# Epoch 9/70
# 10/10 [==============================] - 0s 2ms/step - loss: 25.0100 - lr: 2.5119e-08
# Epoch 10/70
# ...

# %% [markdown]
# ## train no2 library

# %%
import d1no2 as no2
# Out:
# Epoch 1/70
# 10/10 [==============================] - 0s 2ms/step - loss: 28.2049 - lr: 1.0000e-08
# Epoch 2/70
# 10/10 [==============================] - 0s 2ms/step - loss: 28.1961 - lr: 1.1220e-08
# Epoch 3/70
# 10/10 [==============================] - 0s 2ms/step - loss: 28.1828 - lr: 1.2589e-08
# Epoch 4/70
# 10/10 [==============================] - 0s 3ms/step - loss: 28.1668 - lr: 1.4125e-08
# Epoch 5/70
# 10/10 [==============================] - 0s 2ms/step - loss: 28.1484 - lr: 1.5849e-08
# Epoch 6/70
# 10/10 [==============================] - 0s 4ms/step - loss: 28.1273 - lr: 1.7783e-08
# Epoch 7/70
# 10/10 [==============================] - 0s 3ms/step - loss: 28.1036 - lr: 1.9953e-08
# Epoch 8/70
# 10/10 [==============================] - 0s 2ms/step - loss: 28.0769 - lr: 2.2387e-08
# Epoch 9/70
# 10/10 [==============================] - 0s 2ms/step - loss: 28.0470 - lr: 2.5119e-08
# Epoch 10/70
# ...

# %%
import d1co2 as co2
# Out:
# Epoch 1/40
# 10/10 [==============================] - 0s 17ms/step - loss: 1732.4156 - lr: 1.0000e-08
# Epoch 2/40
# 10/10 [==============================] - 0s 2ms/step - loss: 1723.4242 - lr: 1.1220e-08
# Epoch 3/40
# 10/10 [==============================] - 0s 3ms/step - loss: 1709.6659 - lr: 1.2589e-08
# Epoch 4/40
# 10/10 [==============================] - 0s 2ms/step - loss: 1693.4967 - lr: 1.4125e-08
# Epoch 5/40
# 10/10 [==============================] - 0s 3ms/step - loss: 1675.5405 - lr: 1.5849e-08
# Epoch 6/40
# 10/10 [==============================] - 0s 3ms/step - loss: 1655.9128 - lr: 1.7783e-08
# Epoch 7/40
# 10/10 [==============================] - 0s 2ms/step - loss: 1634.0618 - lr: 1.9953e-08
# Epoch 8/40
# 10/10 [==============================] - 0s 3ms/step - loss: 1609.8270 - lr: 2.2387e-08
# Epoch 9/40
# 10/10 [==============================] - 0s 4ms/step - loss: 1583.1871 - lr: 2.5119e-08
# Epoch 10/40
# ...

# %% [markdown]
# ## show output date

# %%
input = '2022-10-23'
print(pm10.pm10(input))
print(pm25.pm25(input))
print(so2.so2(input))
print(co.co(input))
print(o3.o3(input))
print(no2.no2(input))
print(co2.co2(input))
# Out:
#         tanggal      Value
# 360  2022-10-23  58.572052
#         tanggal      Value
# 360  2022-10-23  74.702026
#         tanggal      Value
# 360  2022-10-23  29.059175
#         tanggal     Value
# 360  2022-10-23  11.79926
#         tanggal      Value
# 360  2022-10-23  26.054934
#         tanggal      Value
# 360  2022-10-23  40.353432
#         tanggal        Value
# 360  2022-10-23  1393.333618
